# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import math

# %%
image = np.asarray(Image.open('800x825.jpg').crop((0, 0, 800, 800)).resize((240, 240)))
plt.imshow(image)

# %%
# Out:
# 29.464285714285715
