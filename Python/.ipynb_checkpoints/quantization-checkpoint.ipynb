# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import random
import os
import seaborn as sn
import pandas as pd

# %%
RAW_DIR = 'lab datasets'

CLASSES = []
for subdir in os.listdir(RAW_DIR):
    CLASSES.append(subdir)
    
images = []
for c in CLASSES:
    class_path = os.path.join(RAW_DIR, c)
    for file in os.listdir(class_path):
        file_path = os.path.join(class_path, file)
        
        img = Image.open(file_path)#.resize((120, 120))
        images.append(np.asarray(img).astype(np.float32) / 255.)

random.shuffle(images)
images = np.asarray(images)
plt.imshow(images[0])

# %%
model_name = 'labtest'

model = tf.keras.models.load_model('trained_models/' + model_name)
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_60 (Conv2D)          (None, 60, 60, 16)        448
#
#  batch_normalization_60 (Bat  (None, 60, 60, 16)       64
#  chNormalization)
#
#  max_pooling2d_68 (MaxPoolin  (None, 30, 30, 16)       0
#  g2D)
#
#  conv2d_61 (Conv2D)          (None, 30, 30, 16)        2320
#
#  batch_normalization_61 (Bat  (None, 30, 30, 16)       64
#  chNormalization)
#
#  max_pooling2d_69 (MaxPoolin  (None, 15, 15, 16)       0
#  g2D)
#
#  conv2d_62 (Conv2D)          (None, 15, 15, 32)        4640
#
#  batch_normalization_62 (Bat  (None, 15, 15, 32)       128
#  chNormalization)
#
#  max_pooling2d_70 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  conv2d_63 (Conv2D)          (None, 7, 7, 32)          9248
#
#  batch_normalization_63 (Bat  (None, 7, 7, 32)         128
#  chNormalization)
#
#  max_pooling2d_71 (MaxPoolin  (None, 3, 3, 32)         0
#  g2D)
#
#  conv2d_64 (Conv2D)          (None, 3, 3, 16)          4624
#
#  batch_normalization_64 (Bat  (None, 3, 3, 16)         64
#  chNormalization)
#
#  max_pooling2d_72 (MaxPoolin  (None, 1, 1, 16)         0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 16)                0
#
#  dense_36 (Dense)            (None, 128)               2176
#
#  dropout_24 (Dropout)        (None, 128)               0
#
#  dense_37 (Dense)            (None, 32)                4128
#
#  dropout_25 (Dropout)        (None, 32)                0
#
#  dense_38 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 28,197
# Trainable params: 27,973
# Non-trainable params: 224
# _________________________________________________________________

# %%
quantize_path = f'./quantized_models/{model_name}.tflite'

def representative_data_gen():
  for input_value in tf.data.Dataset.from_tensor_slices(images).batch(1).take(100):
    yield [input_value]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
tflite_model = converter.convert()
tflite_model_size = open(quantize_path, "wb").write(tflite_model)
print("Quantized model is %d bytes" % tflite_model_size)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\flami\AppData\Local\Temp\tmpq5pvcqld\assets
# INFO:tensorflow:Assets written to: C:\Users\flami\AppData\Local\Temp\tmpq5pvcqld\assets
# C:\Users\flami\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [9], in <cell line: 10>()
#       8 converter.optimizations = [tf.lite.Optimize.DEFAULT]
#       9 converter.representative_dataset = representative_data_gen
# ---> 10 tflite_model = converter.convert()
#      11 tflite_model_size = open(quantize_path, "wb").write(tflite_model)
#      12 print("Quantized model is %d bytes" % tflite_model_size)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\lite.py:929, in _export_metrics.<locals>.wrapper(self, *args, **kwargs)
#     926 @functools.wraps(convert_func)
#     927 def wrapper(self, *args, **kwargs):
#     928   # pylint: disable=protected-access
# --> 929   return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\lite.py:908, in TFLiteConverterBase._convert_and_export_metrics(self, convert_func, *args, **kwargs)
#     906 self._save_conversion_params_metric()
#     907 start_time = time.process_time()
# --> 908 result = convert_func(self, *args, **kwargs)
#     909 elapsed_time_ms = (time.process_time() - start_time) * 1000
#     910 if result:
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\lite.py:1338, in TFLiteKerasModelConverterV2.convert(self)
#    1325 @_export_metrics
#    1326 def convert(self):
#    1327   """Converts a keras model based on instance variables.
#    1328
#    1329   Returns:
#    (...)
#    1336       Invalid quantization parameters.
#    1337   """
# -> 1338   saved_model_convert_result = self._convert_as_saved_model()
#    1339   if saved_model_convert_result:
#    1340     return saved_model_convert_result
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\lite.py:1321, in TFLiteKerasModelConverterV2._convert_as_saved_model(self)
#    1317   graph_def, input_tensors, output_tensors = (
#    1318       self._convert_keras_to_saved_model(temp_dir))
#    1319   if self.saved_model_dir:
#    1320     return super(TFLiteKerasModelConverterV2,
# -> 1321                  self).convert(graph_def, input_tensors, output_tensors)
#    1322 finally:
#    1323   shutil.rmtree(temp_dir, True)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\lite.py:1137, in TFLiteConverterBaseV2.convert(self, graph_def, input_tensors, output_tensors)
#    1130 # Converts model.
#    1131 result = _convert_graphdef(
#    1132     input_data=graph_def,
#    1133     input_tensors=input_tensors,
#    1134     output_tensors=output_tensors,
#    1135     **converter_kwargs)
# -> 1137 return self._optimize_tflite_model(
#    1138     result, self._quant_mode, quant_io=self.experimental_new_quantizer)
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert_phase.py:215, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     213 except Exception as error:
#     214   report_error_message(str(error))
# --> 215   raise error from None
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\lite.py:868, in TFLiteConverterBase._optimize_tflite_model(self, model, quant_mode, quant_io)
#     866   q_bias_type = quant_mode.bias_type()
#     867   q_allow_float = quant_mode.is_allow_float()
# --> 868   model = self._quantize(model, q_in_type, q_out_type, q_activations_type,
#     869                          q_bias_type, q_allow_float)
#     871 m_in_type = in_type if in_type else _dtypes.float32
#     872 m_out_type = out_type if out_type else _dtypes.float32
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\lite.py:612, in TFLiteConverterBase._quantize(self, result, input_type, output_type, activations_type, bias_type, allow_float)
#     608 calibrate_quantize = _calibrator.Calibrator(result,
#     609                                             custom_op_registerers_by_name,
#     610                                             custom_op_registerers_by_func)
#     611 if self._experimental_calibrate_only or self.experimental_new_quantizer:
# --> 612   calibrated = calibrate_quantize.calibrate(
#     613       self.representative_dataset.input_gen)
#     615 if self._experimental_calibrate_only:
#     616   return calibrated
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert_phase.py:215, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     213 except Exception as error:
#     214   report_error_message(str(error))
# --> 215   raise error from None
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\optimize\calibrator.py:226, in Calibrator.calibrate(self, dataset_gen)
#     216 @convert_phase(Component.OPTIMIZE_TFLITE_MODEL, SubComponent.CALIBRATE)
#     217 def calibrate(self, dataset_gen):
#     218   """Calibrates the model with specified generator.
#     219
#     220   Returns:
#    (...)
#     224     dataset_gen: A generator that generates calibration samples.
#     225   """
# --> 226   self._feed_tensors(dataset_gen, resize_input=True)
#     227   return self._calibrator.Calibrate()
#
# File ~\miniconda3\envs\tf\lib\site-packages\tensorflow\lite\python\optimize\calibrator.py:138, in Calibrator._feed_tensors(self, dataset_gen, resize_input)
#     136   self._calibrator.FeedTensor(input_array, signature_key)
#     137 else:
# --> 138   self._calibrator.FeedTensor(input_array)
#
# RuntimeError: Attempting to resize dimension 1 of tensor 0 with value 60 to 240. ResizeInputTensorStrict only allows mutating unknown dimensions identified by -1.

# %%
interpreter = tf.lite.Interpreter(model_path=quantize_path)
interpreter.allocate_tensors()

print("== Input details ==")
print("name:", interpreter.get_input_details()[0]['name'])
print("shape:", interpreter.get_input_details()[0]['shape'])
print("type:", interpreter.get_input_details()[0]['dtype'])

print("\n== Output details ==")
print("name:", interpreter.get_output_details()[0]['name'])
print("shape:", interpreter.get_output_details()[0]['shape'])
print("type:", interpreter.get_output_details()[0]['dtype'])

print("\nDUMP INPUT")
print(interpreter.get_input_details()[0])
print("\nDUMP OUTPUT")
print(interpreter.get_output_details()[0])
