# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import random
import os
import seaborn as sn
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator

print(tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.9.1
# Num GPUs Available:  1

# %%
LR = 1e-3
batch_size = 4
epochs = 70
patience = 10
dropout = 0.3
model_name = f'model2_6_lr{LR:.0e}_b{batch_size}_do{dropout}'

input_shape = (240, 240, 3)
num_classes = 6
model = tf.keras.Sequential(
    [
        tf.keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(32, kernel_size=(3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(dropout),
        layers.Dense(64, activation='relu'),
        layers.Dropout(dropout),
        layers.Dense(num_classes, activation='softmax'),
    ]
)
model.summary()
model.compile(optimizer=tf.keras.optimizers.Adam(LR),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])
# Out:
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_198 (Conv2D)         (None, 240, 240, 32)      896
#
#  batch_normalization_136 (Ba  (None, 240, 240, 32)     128
#  tchNormalization)
#
#  max_pooling2d_169 (MaxPooli  (None, 120, 120, 32)     0
#  ng2D)
#
#  conv2d_199 (Conv2D)         (None, 120, 120, 32)      9248
#
#  batch_normalization_137 (Ba  (None, 120, 120, 32)     128
#  tchNormalization)
#
#  max_pooling2d_170 (MaxPooli  (None, 60, 60, 32)       0
#  ng2D)
#
#  conv2d_200 (Conv2D)         (None, 60, 60, 64)        18496
#
#  batch_normalization_138 (Ba  (None, 60, 60, 64)       256
#  tchNormalization)
#
#  max_pooling2d_171 (MaxPooli  (None, 30, 30, 64)       0
#  ng2D)
#
#  conv2d_201 (Conv2D)         (None, 30, 30, 64)        36928
#
#  batch_normalization_139 (Ba  (None, 30, 30, 64)       256
#  tchNormalization)
#
#  max_pooling2d_172 (MaxPooli  (None, 15, 15, 64)       0
#  ng2D)
#
#  conv2d_202 (Conv2D)         (None, 15, 15, 32)        18464
#
#  batch_normalization_140 (Ba  (None, 15, 15, 32)       128
#  tchNormalization)
#
#  max_pooling2d_173 (MaxPooli  (None, 7, 7, 32)         0
#  ng2D)
#
#  flatten_40 (Flatten)        (None, 1568)              0
#
#  dense_117 (Dense)           (None, 128)               200832
#
#  dropout_95 (Dropout)        (None, 128)               0
#
#  dense_118 (Dense)           (None, 64)                8256
#
#  dropout_96 (Dropout)        (None, 64)                0
#
#  dense_119 (Dense)           (None, 6)                 390
#
# =================================================================
# Total params: 294,406
# Trainable params: 293,958
# Non-trainable params: 448
# _________________________________________________________________

# %%
train_generator = ImageDataGenerator(
        rotation_range=90,
        height_shift_range=0.2,
        width_shift_range=0.2,
        shear_range=3,
        brightness_range=(0.5, 1),
        zoom_range=[0.8, 1],
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='reflect',
        rescale=1./255,
)

valid_generator = ImageDataGenerator(
        rotation_range=40,
        brightness_range=(0.5, 1),
        zoom_range=[0.8, 1],
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='reflect',
        rescale=1./255,
)

train_flow = train_generator.flow_from_directory(
        batch_size=batch_size,
        directory=f'datasets/train',
        shuffle=True,
        target_size=(240, 240),
    )

valid_flow = valid_generator.flow_from_directory(
        batch_size=batch_size,
        directory=f'datasets/valid',
        shuffle=True,
        target_size=(240, 240),
    )

test_flow = valid_generator.flow_from_directory(
        batch_size=batch_size,
        directory=f'datasets/test',
        shuffle=False,
        target_size=(240, 240),
    )
# Out:
# Found 451 images belonging to 6 classes.
# Found 57 images belonging to 6 classes.
# Found 56 images belonging to 6 classes.

# %%
STEP_SIZE_TRAIN=train_flow.n//train_flow.batch_size
STEP_SIZE_VALID=valid_flow.n//valid_flow.batch_size

checkpoint = tf.keras.callbacks.ModelCheckpoint(f'trained_models/{model_name}', save_best_only=True)
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience)
history = model.fit(train_flow,
            steps_per_epoch=STEP_SIZE_TRAIN,
            validation_data=valid_flow,
            validation_steps=STEP_SIZE_VALID,
            epochs=epochs,
            callbacks=[stop_early, checkpoint],
)
# Out:
# Epoch 1/70
# 112/112 [==============================] - ETA: 0s - loss: 2.2414 - accuracy: 0.2662
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 12s 101ms/step - loss: 2.2414 - accuracy: 0.2662 - val_loss: 2.0897 - val_accuracy: 0.2679
# Epoch 2/70
# 112/112 [==============================] - 8s 73ms/step - loss: 1.7492 - accuracy: 0.3154 - val_loss: 2.4979 - val_accuracy: 0.2143
# Epoch 3/70
# 112/112 [==============================] - 8s 73ms/step - loss: 1.5932 - accuracy: 0.3758 - val_loss: 3.9401 - val_accuracy: 0.1964
# Epoch 4/70
# 112/112 [==============================] - ETA: 0s - loss: 1.4999 - accuracy: 0.3826
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 11s 99ms/step - loss: 1.4999 - accuracy: 0.3826 - val_loss: 1.5761 - val_accuracy: 0.3036
# Epoch 5/70
# 112/112 [==============================] - 8s 73ms/step - loss: 1.3496 - accuracy: 0.4541 - val_loss: 5.1590 - val_accuracy: 0.2500
# Epoch 6/70
# 112/112 [==============================] - 8s 73ms/step - loss: 1.3463 - accuracy: 0.4474 - val_loss: 5.5734 - val_accuracy: 0.3571
# Epoch 7/70
# 112/112 [==============================] - ETA: 0s - loss: 1.1396 - accuracy: 0.5481
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 11s 99ms/step - loss: 1.1396 - accuracy: 0.5481 - val_loss: 1.5455 - val_accuracy: 0.4821
# Epoch 8/70
# 112/112 [==============================] - ETA: 0s - loss: 1.3137 - accuracy: 0.4832
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 12s 104ms/step - loss: 1.3137 - accuracy: 0.4832 - val_loss: 1.5403 - val_accuracy: 0.4643
# Epoch 9/70
# 112/112 [==============================] - ETA: 0s - loss: 0.9956 - accuracy: 0.6107
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 11s 99ms/step - loss: 0.9956 - accuracy: 0.6107 - val_loss: 1.3364 - val_accuracy: 0.5179
# Epoch 10/70
# 112/112 [==============================] - 8s 72ms/step - loss: 1.0368 - accuracy: 0.6264 - val_loss: 2.9884 - val_accuracy: 0.4643
# Epoch 11/70
# 112/112 [==============================] - ETA: 0s - loss: 0.9815 - accuracy: 0.6331
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 11s 99ms/step - loss: 0.9815 - accuracy: 0.6331 - val_loss: 0.9948 - val_accuracy: 0.5179
# Epoch 12/70
# 112/112 [==============================] - 8s 72ms/step - loss: 0.9959 - accuracy: 0.6421 - val_loss: 2.6712 - val_accuracy: 0.1786
# Epoch 13/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.9939 - accuracy: 0.6465 - val_loss: 3.0290 - val_accuracy: 0.4643
# Epoch 14/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.8195 - accuracy: 0.6913 - val_loss: 3.6140 - val_accuracy: 0.4464
# Epoch 15/70
# 112/112 [==============================] - 8s 72ms/step - loss: 0.7946 - accuracy: 0.7159 - val_loss: 4.3171 - val_accuracy: 0.4107
# Epoch 16/70
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6803 - accuracy: 0.7718 - val_loss: 1.3623 - val_accuracy: 0.6250
# Epoch 17/70
# 112/112 [==============================] - 8s 72ms/step - loss: 0.5635 - accuracy: 0.7897 - val_loss: 1.0993 - val_accuracy: 0.6250
# Epoch 18/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.7775 - accuracy: 0.7069 - val_loss: 2.0101 - val_accuracy: 0.5536
# Epoch 19/70
# 112/112 [==============================] - ETA: 0s - loss: 0.5983 - accuracy: 0.7808
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 11s 99ms/step - loss: 0.5983 - accuracy: 0.7808 - val_loss: 0.6602 - val_accuracy: 0.7143
# Epoch 20/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6625 - accuracy: 0.7494 - val_loss: 1.2070 - val_accuracy: 0.6071
# Epoch 21/70
# 112/112 [==============================] - ETA: 0s - loss: 0.4832 - accuracy: 0.8277
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 11s 99ms/step - loss: 0.4832 - accuracy: 0.8277 - val_loss: 0.4770 - val_accuracy: 0.7500
# Epoch 22/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.5647 - accuracy: 0.8031 - val_loss: 1.8033 - val_accuracy: 0.6071
# Epoch 23/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.5726 - accuracy: 0.8166 - val_loss: 5.0284 - val_accuracy: 0.3393
# Epoch 24/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.5228 - accuracy: 0.8143 - val_loss: 1.4426 - val_accuracy: 0.6071
# Epoch 25/70
# 112/112 [==============================] - 8s 74ms/step - loss: 0.4575 - accuracy: 0.8568 - val_loss: 1.0984 - val_accuracy: 0.6786
# Epoch 26/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4265 - accuracy: 0.8501 - val_loss: 2.8970 - val_accuracy: 0.5000
# Epoch 27/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4529 - accuracy: 0.8300 - val_loss: 1.1242 - val_accuracy: 0.6429
# Epoch 28/70
# 112/112 [==============================] - ETA: 0s - loss: 0.5304 - accuracy: 0.8076
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 12s 104ms/step - loss: 0.5304 - accuracy: 0.8076 - val_loss: 0.4704 - val_accuracy: 0.7857
# Epoch 29/70
# 112/112 [==============================] - ETA: 0s - loss: 0.3862 - accuracy: 0.8546
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 11s 100ms/step - loss: 0.3862 - accuracy: 0.8546 - val_loss: 0.2460 - val_accuracy: 0.8929
# Epoch 30/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3961 - accuracy: 0.8658 - val_loss: 1.1990 - val_accuracy: 0.5893
# Epoch 31/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3363 - accuracy: 0.8949 - val_loss: 1.7956 - val_accuracy: 0.6786
# Epoch 32/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4431 - accuracy: 0.8814 - val_loss: 1.2711 - val_accuracy: 0.6250
# Epoch 33/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4331 - accuracy: 0.8591 - val_loss: 1.0040 - val_accuracy: 0.6786
# Epoch 34/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4935 - accuracy: 0.8479 - val_loss: 0.7268 - val_accuracy: 0.7500
# Epoch 35/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3963 - accuracy: 0.8680 - val_loss: 1.2726 - val_accuracy: 0.6964
# Epoch 36/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3726 - accuracy: 0.8859 - val_loss: 1.7326 - val_accuracy: 0.5536
# Epoch 37/70
# 112/112 [==============================] - ETA: 0s - loss: 0.3585 - accuracy: 0.8702
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# INFO:tensorflow:Assets written to: trained_models\model2_6_lr1e-03_b4_do0.3\assets
# 112/112 [==============================] - 11s 100ms/step - loss: 0.3585 - accuracy: 0.8702 - val_loss: 0.1539 - val_accuracy: 0.9643
# Epoch 38/70
# 112/112 [==============================] - 8s 74ms/step - loss: 0.2873 - accuracy: 0.9105 - val_loss: 1.3393 - val_accuracy: 0.5536
# Epoch 39/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3194 - accuracy: 0.9150 - val_loss: 0.3532 - val_accuracy: 0.8750
# Epoch 40/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3298 - accuracy: 0.9083 - val_loss: 3.3749 - val_accuracy: 0.5357
# Epoch 41/70
# 112/112 [==============================] - 8s 72ms/step - loss: 0.5147 - accuracy: 0.8434 - val_loss: 3.3434 - val_accuracy: 0.3393
# Epoch 42/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3268 - accuracy: 0.8993 - val_loss: 0.1867 - val_accuracy: 0.9464
# Epoch 43/70
# 112/112 [==============================] - 8s 72ms/step - loss: 0.2588 - accuracy: 0.9016 - val_loss: 0.9619 - val_accuracy: 0.6250
# Epoch 44/70
# 112/112 [==============================] - 8s 72ms/step - loss: 0.2592 - accuracy: 0.9083 - val_loss: 0.4409 - val_accuracy: 0.8393
# Epoch 45/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3587 - accuracy: 0.8993 - val_loss: 1.9984 - val_accuracy: 0.5357
# Epoch 46/70
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3035 - accuracy: 0.8926 - val_loss: 0.2327 - val_accuracy: 0.8929
# Epoch 47/70
# 112/112 [==============================] - 8s 72ms/step - loss: 0.3895 - accuracy: 0.8814 - val_loss: 1.5680 - val_accuracy: 0.4821

# %%
# Save training history
hist_df = pd.DataFrame(history.history) 
hist_csv_file = f'trained_models/{model_name}/history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
model = tf.keras.models.load_model('trained_models/' + model_name) #model_name

test_flow.reset()

scores = model.evaluate(test_flow)

print("%s%s: %.2f%%" % ("evaluate ", model.metrics_names[1], scores[1]*100))
# Out:
# 14/14 [==============================] - 1s 65ms/step - loss: 0.2314 - accuracy: 0.8929
# evaluate accuracy: 89.29%

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
CLASSES = []
for subdir in os.listdir('raw_datasets'):
    CLASSES.append(subdir)
    
print(CLASSES)
    
index = 2
img_num = 34

TEST_IMAGES = []
TEST_LABELS = []
for subdir in os.listdir('datasets/test'):
    for file in os.listdir(os.path.join('datasets', 'test', subdir)):
        TEST_IMAGES.append(np.asarray(Image.open(f'datasets/test/{subdir}/{file}')).astype(np.float32)/255.)
        TEST_LABELS.append(CLASSES.index(subdir))
        
TEST_IMAGES = np.asarray(TEST_IMAGES)
TEST_LABELS = np.asarray(TEST_LABELS)
        
img = np.asarray(Image.open(f'raw_datasets/{CLASSES[index]}/{img_num}.jpg')).astype(np.float32)/255.
img = np.expand_dims(img, axis=0)
pred = model.predict(img)
print(CLASSES[np.argmax(pred)])
# Out:
# ['gray painted wood', 'gray rug', 'gray wood', 'light brown wood', 'rubber stairs', 'stone tile']
# 1/1 [==============================] - 0s 155ms/step
# light brown wood

# %%
file_name = f'./confusion_matrix/confusion_matrix_{num_classes}class_{model_name}'
title = f'Material (6) Classification'

if not os.path.exists('./confusion_matrix'):
  os.mkdir('./confusion_matrix')

test_labels = test_flow.class_indices
print(test_labels)
predictions = tf.math.argmax(model.predict(TEST_IMAGES), axis=1)
cf = tf.math.confusion_matrix(TEST_LABELS, predictions).numpy()
cf = cf / cf.sum(axis=1)[:, np.newaxis]
df = pd.DataFrame(cf, index=CLASSES, columns=CLASSES)
plt.figure(figsize=(15, 15))
sn.set(font_scale=1.8)
hm = sn.heatmap(df, annot=True, cmap='Blues', square=True, fmt='.2f')
plt.xlabel('Predicted label', labelpad=40)
plt.ylabel('Actual label', labelpad=40)
plt.title(title, y=1.03, pad=20, fontsize=30)
plt.savefig(file_name + '_transparent.png', transparent=True)
plt.savefig(file_name + '_white.png', transparent=False, facecolor='white')
# Out:
# {'gray painted wood': 0, 'gray rug': 1, 'gray wood': 2, 'light brown wood': 3, 'rubber stairs': 4, 'stone tile': 5}
# 2/2 [==============================] - 0s 197ms/step
